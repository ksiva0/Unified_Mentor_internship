# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\master\Downloads\Crop Production data.csv")
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
df.isna().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
null_values = df.loc[df["Production"].isna()]
null_values
# Out:
#                          State_Name   District_Name  Crop_Year       Season  \
# 46      Andaman and Nicobar Islands        NICOBARS       2005  Whole Year
# 51      Andaman and Nicobar Islands        NICOBARS       2005  Whole Year
# 623                  Andhra Pradesh       ANANTAPUR       2007  Kharif
# 630                  Andhra Pradesh       ANANTAPUR       2007  Rabi
# 698                  Andhra Pradesh       ANANTAPUR       2009  Rabi
# ...                             ...             ...        ...          ...
# 244128                  West Bengal  MEDINIPUR WEST       2010  Rabi
# 244581                  West Bengal     MURSHIDABAD       2006  Kharif
# 245606                  West Bengal         PURULIA       2001  Rabi
# 245644                  West Bengal         PURULIA       2002  Rabi
# 245865                  West Bengal         PURULIA       2008  Rabi
#
#                          Crop     Area  Production
# 46                   Arecanut   795.67         NaN
# ...

# %%
mean = df["Production"].mean()
mean
# Out:
# 582503.4422509808

# %%
median = df["Production"].median()
median
# Out:
# 729.0

# %%
df["Production"].fillna(median, inplace=True)  # Fill NaN values in "Production" column with b
values = df[df["Production"].isna()]  # Filter DataFrame to include only rows where "Production" is NaN

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
df.isna().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
df.describe().T
# Out:
#                count           mean           std      min     25%     50%  \
# Crop_Year   246091.0    2005.643018  4.952164e+00  1997.00  2002.0  2006.0
# Area        246091.0   12002.820864  5.052340e+04     0.04    80.0   582.0
# Production  246091.0  573685.490072  1.693613e+07     0.00    91.0   729.0
#
#                75%           max
# Crop_Year   2010.0  2.015000e+03
# Area        4392.0  8.580100e+06
# Production  6769.0  1.250800e+09

# %%
correlation = df[['Area', 'Production']].corr()
correlation
# Out:
#                 Area  Production
# Area        1.000000    0.040655
# Production  0.040655    1.000000

# %%
grouped_data = df.groupby(["Crop_Year", "Season"])["Production"].sum().reset_index()
grouped_data
# Out:
#      Crop_Year       Season   Production
# 0         1997  Autumn         3018718.0
# 1         1997  Kharif       138280321.0
# 2         1997  Rabi         120346325.0
# 3         1997  Summer         7458988.0
# 4         1997  Whole Year   560945202.0
# ..         ...          ...          ...
# 108       2015  Autumn          530059.2
# 109       2015  Kharif           99478.0
# 110       2015  Rabi              3938.0
# 111       2015  Summer          899466.3
# 112       2015  Winter         5402852.2
#
# [113 rows x 3 columns]

# %%
grouped_df = df.groupby(["Crop_Year", "Season"])["Production"].sum().reset_index()

# Plotting with seaborn
plt.figure(figsize=(12, 6))

# Create a bar plot
sns.lineplot(data=grouped_df, y="Crop_Year", x="Production", hue="Season")

# Adding labels and title
plt.xlabel("Crop Year")
plt.ylabel("Total Production")
plt.title("Total Production by Crop Year and Season")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
season_production = df.groupby("Season")["Production"].sum().reset_index()
season_production
# Out:
#         Season    Production
# 0  Autumn       6.442762e+07
# 1  Kharif       4.031186e+09
# 2  Rabi         2.052290e+09
# 3  Summer       1.706798e+08
# 4  Whole Year   1.344257e+11
# 5  Winter       4.345557e+08

# %%
season_production.plot.bar()
# Out:
# <Axes: >

# %%
sns.barplot(data=df, y="State_Name", x="Area")
# Out:
# <Axes: xlabel='Area', ylabel='State_Name'>

# %%
df["State_Name"].value_counts().plot(kind="bar", figsize=(12,7))
# Out:
# <Axes: xlabel='State_Name'>

# %%
df.groupby("State_Name")["Production"].sum().plot(kind="kde", figsize=(16,7))
# Out:
# <Axes: ylabel='Density'>

# %%
df.groupby(["Crop"])["Area"].sum().plot(kind="kde", figsize=(16,7))
# Out:
# <Axes: ylabel='Density'>

# %%
dist_area = df.groupby("District_Name")["Area"].sum()
dist_area
# Out:
# District_Name
# 24 PARAGANAS NORTH    12478029.0
# 24 PARAGANAS SOUTH     9307672.0
# ADILABAD               9656437.0
# AGAR MALWA              276040.0
# AGRA                   7088628.0
#                          ...
# YADGIR                 1920159.0
# YAMUNANAGAR            2922113.0
# YANAM                    17652.0
# YAVATMAL              15346055.0
# ZUNHEBOTO               614855.0
# Name: Area, Length: 646, dtype: float64

# %%
dist_area.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
state_area = df.groupby("State_Name")["Area"].sum()
state_area
# Out:
# State_Name
# Andaman and Nicobar Islands    3.378961e+05
# Andhra Pradesh                 1.315458e+08
# Arunachal Pradesh              4.364346e+06
# Assam                          7.037876e+07
# Bihar                          1.282720e+08
# Chandigarh                     1.252200e+04
# Chhattisgarh                   8.303966e+07
# Dadra and Nagar Haveli         3.965150e+05
# Goa                            1.205680e+06
# Gujarat                        1.549440e+08
# Haryana                        8.959731e+07
# Himachal Pradesh               1.000388e+07
# Jammu and Kashmir              9.264623e+06
# Jharkhand                      9.391046e+06
# Karnataka                      2.029101e+08
# Kerala                         3.190807e+07
# Madhya Pradesh                 3.298131e+08
# Maharashtra                    3.222062e+08
# Manipur                        2.007264e+06
# Meghalaya                      4.035028e+06
# Mizoram                        9.937352e+05
# ...

# %%
state_area.plot.bar(figsize=(15,8))
# Out:
# <Axes: xlabel='State_Name'>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Crop_Year', y='Production', data=df, estimator=np.sum, ci=None)
plt.title('Total Production by Crop Year')
plt.xlabel('Crop Year')
plt.ylabel('Total Production')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 15))
sns.barplot(y='Crop', x='Area', data=df, estimator=np.sum, ci=None)
plt.title('Total Area by Crop')
plt.xlabel('Crop')
plt.ylabel('Total Area')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Area', y='Production', hue='Crop_Year', data=df)
plt.title('Production vs Area by Crop Year')
plt.xlabel('Area')
plt.ylabel('Production')
plt.legend(title='Crop Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data=df, x='Crop_Year', y='Production', marker='o')
plt.title('Production by Crop over the Years')
plt.xlabel('Crop Year')
plt.ylabel('Production')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
correlation = df[['Area', 'Production']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation between Area and Production')
plt.show()

# %%
if 'State_Name' in df.columns:
    production_by_state = df.groupby(['State_Name', 'Crop_Year'])['Production'].sum().unstack()
    production_by_state.plot(kind='bar', stacked=True, figsize=(14, 8))
    plt.title('Total Production by State and Crop Year')
    plt.xlabel('State')
    plt.ylabel('Total Production')
    plt.legend(title='Crop Year', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Crop_Year', y='Production', hue='Crop', style='State_Name')
plt.title('Crop Production Over the Years by State and District')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure(figsize=(12, 6))
# ----> 2 sns.lineplot(data=df, x='Crop_Year', y='Production', hue='Crop', style='State_Name')
#       3 plt.title('Crop Production Over the Years by State and District')
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:441, in _LinePlotter.plot(self, ax, kws)
# ...

# %%
pivot_table = df.pivot_table(index='District_Name', columns='Crop', values='Production', aggfunc='sum')
plt.figure(figsize=(14, 10))
sns.heatmap(pivot_table, cmap='YlGnBu', linewidths=0.1)
plt.title('Crop Diversity in Different Districts/States')
plt.show()

# %%
g = sns.FacetGrid(df, col='Season', col_wrap=3, height=4, aspect=1.5)
g.map(sns.lineplot, 'Crop_Year', 'Production').add_legend()
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Production Trends for Specific Crops by Season')
plt.show()

# %%
sns.pairplot(df, vars=['Area', 'Production'])
plt.suptitle('Correlation Between Area and Production for Different Crops', y=1.02)
plt.show()

# %%
specific_crop = 'Rice' 
top_districts = df[df['Crop'] == specific_crop].groupby('District_Name')['Production'].sum().nlargest(10)
plt.figure(figsize=(12, 6))
top_districts.plot.bar()
plt.title(f'Top Producing Districts for {specific_crop}')
plt.ylabel('Production')
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.lineplot(data=df, x='Season', y='Production')
plt.title('Seasonal Variations in Crop Production')
plt.show()

# %%
area_by_year = df.pivot_table(index='Crop_Year', columns='Crop', values='Area', aggfunc='sum')
area_by_year.plot.area(figsize=(12, 6))
plt.title('Total Area Cultivated for Each Crop by Year')
plt.ylabel('Area')
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df, x='Production', multiple='stack', bins=10)
plt.title('Distribution of Production Across Different Crops')
plt.xlabel('Production')
plt.ylabel('Frequency')
plt.show()

# %%
heatmap_data = df.pivot_table(index='Crop_Year', columns='Season', values='Production', aggfunc='sum')
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt='.1f', cmap='YlGnBu')
plt.title('Temporal Heatmap of Crop Production')
plt.ylabel('Year')
plt.xlabel('Season')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Crop_Year', y='Production', hue='State_Name', data=df)
plt.title('Production over Years by State')
plt.show()

# %% [markdown]
# ### Conclusion
#
# <b>Advancement through B2B Collaboration Platforms</b>: The agriculture sector is set to transform with the development of Business-to-Business collaboration platforms that enable effective and flexible interactions among various stakeholders, enhancing cooperation and efficiency within the agri-food industry.
#
# <b>Data-Driven Crop Production Insights</b>: Utilizing extensive crop production data from India, the aim is to predict future yields and identify key indicators influencing agricultural output, thereby optimizing farming practices and supporting sustainable growth in the agriculture sector.
